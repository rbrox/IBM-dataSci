# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file_path = "./data/train.csv"
train_data_set = pd.read_csv(file_path)

train_data_set.dtypes
# Out:
# id               int64
# date            object
# store_nbr        int64
# family          object
# sales          float64
# onpromotion      int64
# dtype: object

# %%
train_data_set['date'] = pd.to_datetime(train_data_set['date'])

family = list(train_data_set['family'].unique())
dummy = pd.get_dummies(train_data_set['family'])

merged_df = pd.merge(train_data_set, dummy, left_index=True, right_index=True)
merged_df.drop('id', inplace=True, axis=1)
merged_df.drop('family', inplace=True, axis=1)
merged_df
# Out:
#               date  store_nbr     sales  onpromotion  AUTOMOTIVE  BABY CARE
# 0       2013-01-01          1     0.000            0        True      False  \
# 1       2013-01-01          1     0.000            0       False       True
# 2       2013-01-01          1     0.000            0       False      False
# 3       2013-01-01          1     0.000            0       False      False
# 4       2013-01-01          1     0.000            0       False      False
# ...            ...        ...       ...          ...         ...        ...
# 3000883 2017-08-15          9   438.133            0       False      False
# 3000884 2017-08-15          9   154.553            1       False      False
# 3000885 2017-08-15          9  2419.729          148       False      False
# 3000886 2017-08-15          9   121.000            8       False      False
# 3000887 2017-08-15          9    16.000            0       False      False
#
#          BEAUTY  BEVERAGES  BOOKS  BREAD/BAKERY  ...  MAGAZINES  MEATS
# 0         False      False  False         False  ...      False  False  \
# 1         False      False  False         False  ...      False  False
# 2          True      False  False         False  ...      False  False
# 3         False       True  False         False  ...      False  False
# 4         False      False   True         False  ...      False  False
# ...         ...        ...    ...           ...  ...        ...    ...
# 3000883   False      False  False         False  ...      False  False
# 3000884   False      False  False         False  ...      False  False
# 3000885   False      False  False         False  ...      False  False
# 3000886   False      False  False         False  ...      False  False
# 3000887   False      False  False         False  ...      False  False
#
#          PERSONAL CARE  PET SUPPLIES  PLAYERS AND ELECTRONICS  POULTRY
# 0                False         False                    False    False  \
# 1                False         False                    False    False
# 2                False         False                    False    False
# 3                False         False                    False    False
# 4                False         False                    False    False
# ...                ...           ...                      ...      ...
# 3000883          False         False                    False     True
# 3000884          False         False                    False    False
# 3000885          False         False                    False    False
# 3000886          False         False                    False    False
# 3000887          False         False                    False    False
#
#          PREPARED FOODS  PRODUCE  SCHOOL AND OFFICE SUPPLIES  SEAFOOD
# 0                 False    False                       False    False
# 1                 False    False                       False    False
# 2                 False    False                       False    False
# 3                 False    False                       False    False
# 4                 False    False                       False    False
# ...                 ...      ...                         ...      ...
# 3000883           False    False                       False    False
# 3000884            True    False                       False    False
# 3000885           False     True                       False    False
# 3000886           False    False                        True    False
# 3000887           False    False                       False     True
#
# [3000888 rows x 37 columns]

# %%
merged_df.describe()
# Out:
#                                 date     store_nbr         sales   onpromotion
# count                        3000888  3.000888e+06  3.000888e+06  3.000888e+06
# mean   2015-04-24 08:27:04.703088384  2.750000e+01  3.577757e+02  2.602770e+00
# min              2013-01-01 00:00:00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%              2014-02-26 18:00:00  1.400000e+01  0.000000e+00  0.000000e+00
# 50%              2015-04-24 12:00:00  2.750000e+01  1.100000e+01  0.000000e+00
# 75%              2016-06-19 06:00:00  4.100000e+01  1.958473e+02  0.000000e+00
# max              2017-08-15 00:00:00  5.400000e+01  1.247170e+05  7.410000e+02
# std                              NaN  1.558579e+01  1.101998e+03  1.221888e+01

# %%
merged_df.isna()
# Out:
#           date  store_nbr  sales  onpromotion  AUTOMOTIVE  BABY CARE  BEAUTY
# 0        False      False  False        False       False      False   False  \
# 1        False      False  False        False       False      False   False
# 2        False      False  False        False       False      False   False
# 3        False      False  False        False       False      False   False
# 4        False      False  False        False       False      False   False
# ...        ...        ...    ...          ...         ...        ...     ...
# 3000883  False      False  False        False       False      False   False
# 3000884  False      False  False        False       False      False   False
# 3000885  False      False  False        False       False      False   False
# 3000886  False      False  False        False       False      False   False
# 3000887  False      False  False        False       False      False   False
#
#          BEVERAGES  BOOKS  BREAD/BAKERY  ...  MAGAZINES  MEATS  PERSONAL CARE
# 0            False  False         False  ...      False  False          False  \
# 1            False  False         False  ...      False  False          False
# 2            False  False         False  ...      False  False          False
# 3            False  False         False  ...      False  False          False
# 4            False  False         False  ...      False  False          False
# ...            ...    ...           ...  ...        ...    ...            ...
# 3000883      False  False         False  ...      False  False          False
# 3000884      False  False         False  ...      False  False          False
# 3000885      False  False         False  ...      False  False          False
# 3000886      False  False         False  ...      False  False          False
# 3000887      False  False         False  ...      False  False          False
#
#          PET SUPPLIES  PLAYERS AND ELECTRONICS  POULTRY  PREPARED FOODS
# 0               False                    False    False           False  \
# 1               False                    False    False           False
# 2               False                    False    False           False
# 3               False                    False    False           False
# 4               False                    False    False           False
# ...               ...                      ...      ...             ...
# 3000883         False                    False    False           False
# 3000884         False                    False    False           False
# 3000885         False                    False    False           False
# 3000886         False                    False    False           False
# 3000887         False                    False    False           False
#
#          PRODUCE  SCHOOL AND OFFICE SUPPLIES  SEAFOOD
# 0          False                       False    False
# 1          False                       False    False
# 2          False                       False    False
# 3          False                       False    False
# 4          False                       False    False
# ...          ...                         ...      ...
# 3000883    False                       False    False
# 3000884    False                       False    False
# 3000885    False                       False    False
# 3000886    False                       False    False
# 3000887    False                       False    False
#
# [3000888 rows x 37 columns]

# %%
merged_df.isnull()
# Out:
#           date  store_nbr  sales  onpromotion  AUTOMOTIVE  BABY CARE  BEAUTY
# 0        False      False  False        False       False      False   False  \
# 1        False      False  False        False       False      False   False
# 2        False      False  False        False       False      False   False
# 3        False      False  False        False       False      False   False
# 4        False      False  False        False       False      False   False
# ...        ...        ...    ...          ...         ...        ...     ...
# 3000883  False      False  False        False       False      False   False
# 3000884  False      False  False        False       False      False   False
# 3000885  False      False  False        False       False      False   False
# 3000886  False      False  False        False       False      False   False
# 3000887  False      False  False        False       False      False   False
#
#          BEVERAGES  BOOKS  BREAD/BAKERY  ...  MAGAZINES  MEATS  PERSONAL CARE
# 0            False  False         False  ...      False  False          False  \
# 1            False  False         False  ...      False  False          False
# 2            False  False         False  ...      False  False          False
# 3            False  False         False  ...      False  False          False
# 4            False  False         False  ...      False  False          False
# ...            ...    ...           ...  ...        ...    ...            ...
# 3000883      False  False         False  ...      False  False          False
# 3000884      False  False         False  ...      False  False          False
# 3000885      False  False         False  ...      False  False          False
# 3000886      False  False         False  ...      False  False          False
# 3000887      False  False         False  ...      False  False          False
#
#          PET SUPPLIES  PLAYERS AND ELECTRONICS  POULTRY  PREPARED FOODS
# 0               False                    False    False           False  \
# 1               False                    False    False           False
# 2               False                    False    False           False
# 3               False                    False    False           False
# 4               False                    False    False           False
# ...               ...                      ...      ...             ...
# 3000883         False                    False    False           False
# 3000884         False                    False    False           False
# 3000885         False                    False    False           False
# 3000886         False                    False    False           False
# 3000887         False                    False    False           False
#
#          PRODUCE  SCHOOL AND OFFICE SUPPLIES  SEAFOOD
# 0          False                       False    False
# 1          False                       False    False
# 2          False                       False    False
# 3          False                       False    False
# 4          False                       False    False
# ...          ...                         ...      ...
# 3000883    False                       False    False
# 3000884    False                       False    False
# 3000885    False                       False    False
# 3000886    False                       False    False
# 3000887    False                       False    False
#
# [3000888 rows x 37 columns]

# %%
merged_df.dtypes
# Out:
# date                          datetime64[ns]
# store_nbr                              int64
# sales                                float64
# onpromotion                            int64
# AUTOMOTIVE                              bool
# BABY CARE                               bool
# BEAUTY                                  bool
# BEVERAGES                               bool
# BOOKS                                   bool
# BREAD/BAKERY                            bool
# CELEBRATION                             bool
# CLEANING                                bool
# DAIRY                                   bool
# DELI                                    bool
# EGGS                                    bool
# FROZEN FOODS                            bool
# GROCERY I                               bool
# GROCERY II                              bool
# HARDWARE                                bool
# HOME AND KITCHEN I                      bool
# HOME AND KITCHEN II                     bool
# HOME APPLIANCES                         bool
# HOME CARE                               bool
# LADIESWEAR                              bool
# LAWN AND GARDEN                         bool
# LINGERIE                                bool
# LIQUOR,WINE,BEER                        bool
# MAGAZINES                               bool
# MEATS                                   bool
# PERSONAL CARE                           bool
# PET SUPPLIES                            bool
# PLAYERS AND ELECTRONICS                 bool
# POULTRY                                 bool
# PREPARED FOODS                          bool
# PRODUCE                                 bool
# SCHOOL AND OFFICE SUPPLIES              bool
# SEAFOOD                                 bool
# dtype: object

# %% [markdown]
# Dependent Variable : Sales
# Independent Variable (Features) : the rest

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
merged_df['year'] = merged_df['date'].dt.year
merged_df['month'] = merged_df['date'].dt.month
merged_df['day'] = merged_df['date'].dt.day
merged_df.drop('date', axis=1, inplace=True)
features = list (merged_df.columns)
features.remove('sales')


X_train, X_test, y_train, y_test = train_test_split(merged_df[features], merged_df['sales'], test_size=0.2, random_state=42)  

X_train
# Out:
#          store_nbr  onpromotion  AUTOMOTIVE  BABY CARE  BEAUTY  BEVERAGES
# 2902383         45            2        True      False   False      False  \
# 1651514         47            0       False      False   False      False
# 1948349         26            0       False      False   False      False
# 2893871          7            1       False      False    True      False
# 2867501         16            0       False      False   False      False
# ...            ...          ...         ...        ...     ...        ...
# 1692743         54            0       False      False   False      False
# 2356330         23            0       False      False   False      False
# 2229084         53            0        True      False   False      False
# 2768307         33           15       False      False   False       True
# 2219110         23            2       False      False   False      False
#
#          BOOKS  BREAD/BAKERY  CELEBRATION  CLEANING  ...  PET SUPPLIES
# 2902383  False         False        False     False  ...         False  \
# 1651514  False         False        False     False  ...         False
# 1948349  False         False        False     False  ...         False
# 2893871  False         False        False     False  ...         False
# 2867501  False         False        False     False  ...         False
# ...        ...           ...          ...       ...  ...           ...
# 1692743  False         False        False     False  ...         False
# 2356330  False         False        False     False  ...         False
# 2229084  False         False        False     False  ...         False
# 2768307  False         False        False     False  ...         False
# 2219110  False         False        False     False  ...         False
#
#          PLAYERS AND ELECTRONICS  POULTRY  PREPARED FOODS  PRODUCE
# 2902383                    False    False           False    False  \
# 1651514                    False    False            True    False
# 1948349                    False    False            True    False
# 2893871                    False    False           False    False
# 2867501                    False    False           False    False
# ...                          ...      ...             ...      ...
# 1692743                    False    False           False    False
# 2356330                    False    False           False    False
# 2229084                    False    False           False    False
# 2768307                    False    False           False    False
# 2219110                    False    False           False    False
#
#          SCHOOL AND OFFICE SUPPLIES  SEAFOOD  year  month  day
# 2902383                       False    False  2017      6   21
# 1651514                       False    False  2015      7   18
# 1948349                       False    False  2016      1    2
# 2893871                       False    False  2017      6   16
# 2867501                       False     True  2017      6    2
# ...                             ...      ...   ...    ...  ...
# 1692743                       False    False  2015      8   10
# 2356330                        True    False  2016      8   18
# 2229084                       False    False  2016      6    7
# 2768307                       False    False  2017      4    7
# 2219110                       False    False  2016      6    2
#
# [2400710 rows x 38 columns]

# %%
model = LinearRegression()

print(X_train.dtypes)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# store_nbr                     int64
# onpromotion                   int64
# AUTOMOTIVE                     bool
# BABY CARE                      bool
# BEAUTY                         bool
# BEVERAGES                      bool
# BOOKS                          bool
# BREAD/BAKERY                   bool
# CELEBRATION                    bool
# CLEANING                       bool
# DAIRY                          bool
# DELI                           bool
# EGGS                           bool
# FROZEN FOODS                   bool
# GROCERY I                      bool
# GROCERY II                     bool
# HARDWARE                       bool
# HOME AND KITCHEN I             bool
# HOME AND KITCHEN II            bool
# HOME APPLIANCES                bool
# HOME CARE                      bool
# LADIESWEAR                     bool
# LAWN AND GARDEN                bool
# LINGERIE                       bool
# LIQUOR,WINE,BEER               bool
# MAGAZINES                      bool
# MEATS                          bool
# PERSONAL CARE                  bool
# PET SUPPLIES                   bool
# PLAYERS AND ELECTRONICS        bool
# POULTRY                        bool
# PREPARED FOODS                 bool
# PRODUCE                        bool
# SCHOOL AND OFFICE SUPPLIES     bool
# SEAFOOD                        bool
# year                          int32
# month                         int32
# day                           int32
# dtype: object
# 577587.8597124695

# %%
print(mse)
# Out:
# 577587.8597124695

# %%
merged_df.describe()
# Out:
#           store_nbr         sales   onpromotion          year         month
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06  \
# mean   2.750000e+01  3.577757e+02  2.602770e+00  2.014838e+03  6.207838e+00
# std    1.558579e+01  1.101998e+03  1.221888e+01  1.345518e+00  3.385668e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00  2.013000e+03  1.000000e+00
# 25%    1.400000e+01  0.000000e+00  0.000000e+00  2.014000e+03  3.000000e+00
# 50%    2.750000e+01  1.100000e+01  0.000000e+00  2.015000e+03  6.000000e+00
# 75%    4.100000e+01  1.958473e+02  0.000000e+00  2.016000e+03  9.000000e+00
# max    5.400000e+01  1.247170e+05  7.410000e+02  2.017000e+03  1.200000e+01
#
#                 day
# count  3.000888e+06
# mean   1.563005e+01
# std    8.794789e+00
# min    1.000000e+00
# 25%    8.000000e+00
# 50%    1.600000e+01
# 75%    2.300000e+01
# max    3.100000e+01

# %%
merged_df.to_csv('./data_clean/train.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 merged_df.to_csv('./data_clean/train.csv', index = False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data_clean'
