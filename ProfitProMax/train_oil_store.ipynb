# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file_path = "./data/"
df_store = pd.read_csv(file_path + 'stores.csv')
df_trcs = pd.read_csv(file_path + 'transactions.csv')

# %%
df_store
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
df_store.dtypes
# Out:
# store_nbr     int64
# city         object
# state        object
# type         object
# cluster       int64
# dtype: object

# %%
types = sorted(list(df_store['type'].unique()))
print(types)

map_dict = {
            'A' : 1,
            'B' : 2, 
            'C' : 3, 
            'D' : 4,
            'E' : 5     
}

df_store['type_id'] = df_store['type'].map(map_dict)
df_store
# Out:
# ['A', 'B', 'C', 'D', 'E']
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13  \
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
df_store['state'].unique()
# Out:
# array(['Pichincha', 'Santo Domingo de los Tsachilas', 'Cotopaxi',
#        'Chimborazo', 'Imbabura', 'Bolivar', 'Pastaza', 'Tungurahua',
#        'Guayas', 'Santa Elena', 'Los Rios', 'Azuay', 'Loja', 'El Oro',
#        'Esmeraldas', 'Manabi'], dtype=object)

# %%
states = list(df_store['state'].unique())
dummy = pd.get_dummies(df_store['state'])

merged_df = pd.merge(df_store, dummy, left_index=True, right_index=True)
merged_df.drop('state', inplace=True, axis=1)
df_store = merged_df
df_store
# Out:
#     store_nbr           city type  cluster  type_id  Azuay  Bolivar
# 0           1          Quito    D       13        4  False    False  \
# 1           2          Quito    D       13        4  False    False
# 2           3          Quito    D        8        4  False    False
# 3           4          Quito    D        9        4  False    False
# 4           5  Santo Domingo    D        4        4  False    False
# 5           6          Quito    D       13        4  False    False
# 6           7          Quito    D        8        4  False    False
# 7           8          Quito    D        8        4  False    False
# 8           9          Quito    B        6        2  False    False
# 9          10          Quito    C       15        3  False    False
# 10         11        Cayambe    B        6        2  False    False
# 11         12      Latacunga    C       15        3  False    False
# 12         13      Latacunga    C       15        3  False    False
# ...

# %%
cities = list(df_store['city'].unique())
print(cities)
# Out:
# ['Quito', 'Santo Domingo', 'Cayambe', 'Latacunga', 'Riobamba', 'Ibarra', 'Guaranda', 'Puyo', 'Ambato', 'Guayaquil', 'Salinas', 'Daule', 'Babahoyo', 'Quevedo', 'Playas', 'Libertad', 'Cuenca', 'Loja', 'Machala', 'Esmeraldas', 'Manta', 'El Carmen']

# %%
cities = list(df_store['city'].unique())
dummy = pd.get_dummies(df_store['city'])

merged_df = pd.merge(df_store, dummy, left_index=True, right_index=True)
merged_df.drop('city', inplace=True, axis=1)
df_store = merged_df
df_store.drop('type', inplace=True, axis=1)
# Out:
#     store_nbr type  cluster  type_id  Azuay  Bolivar  Chimborazo  Cotopaxi
# 0           1    D       13        4  False    False       False     False  \
# 1           2    D       13        4  False    False       False     False
# 2           3    D        8        4  False    False       False     False
# 3           4    D        9        4  False    False       False     False
# 4           5    D        4        4  False    False       False     False
# 5           6    D       13        4  False    False       False     False
# 6           7    D        8        4  False    False       False     False
# 7           8    D        8        4  False    False       False     False
# 8           9    B        6        2  False    False       False     False
# 9          10    C       15        3  False    False       False     False
# 10         11    B        6        2  False    False       False     False
# ...
