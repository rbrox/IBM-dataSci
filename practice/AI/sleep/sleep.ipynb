# %% [markdown]
# # *Loading data*

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

# %% [markdown]
# Loading the data

# %%
file_path = './Sleep_Efficiency.csv'
data_frame = pd.read_csv(file_path)
data_frame.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %% [markdown]
# Preliminary Plots

# %%
# Generate scatter plots for all pairs of variables
pd.plotting.scatter_matrix(data_frame, figsize=(10, 10))

plt.show()

# %%
# Description
data_frame.describe()
# Out:
#                ID         Age  Sleep duration  Sleep efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %% [markdown]
# Plotting the correlation matrix

# %% [markdown]
# Plotting Failed hence the data is not clean.

# %% [markdown]
# # *Data Exploration*

# %%
data_frame.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %% [markdown]
# Finding null rows using the `isna()` or `isnull()` function

# %%
na_rows = data_frame[data_frame.isna().any(axis=1)]
print(na_rows)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 19    20   52    Male  2021-12-03 00:30:00  2021-12-03 07:30:00
# 20    21   24    Male  2021-05-02 00:00:00  2021-05-02 08:00:00
# 24    25   24    Male  2021-09-16 00:00:00  2021-09-16 07:00:00
# 26    27   36  Female  2021-06-18 00:00:00  2021-06-18 07:00:00
# ..   ...  ...     ...                  ...                  ...
# 434  435   28  Female  2021-08-11 23:00:00  2021-08-11 07:00:00
# 440  441   28  Female  2021-02-06 21:00:00  2021-02-06 05:00:00
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 5               7.5              0.90                    23
# 19              7.0              0.89                    28
# ...

# %% [markdown]
# **Removing the NaN rows**

# %%
data_frame.dropna(inplace = True)
print(data_frame)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 445  446   30  Female  2021-11-16 23:00:00  2021-11-16 06:30:00
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
data_frame.corr(numeric_only= True)
# Out:
#                               ID       Age  Sleep duration  Sleep efficiency  \
# ID                      1.000000  0.012011        0.030504          0.025931
# Age                     0.012011  1.000000       -0.065951          0.124093
# Sleep duration          0.030504 -0.065951        1.000000         -0.019164
# Sleep efficiency        0.025931  0.124093       -0.019164          1.000000
# REM sleep percentage    0.086319  0.015449       -0.015408          0.064038
# Deep sleep percentage  -0.015469  0.058156       -0.035477          0.789087
# Light sleep percentage -0.003608 -0.062613        0.039536         -0.816934
# Awakenings             -0.084746 -0.004006       -0.009162         -0.567885
# Caffeine consumption   -0.056247 -0.169057       -0.030922          0.070804
# Alcohol consumption     0.089620  0.069295       -0.048436         -0.397012
# Exercise frequency      0.009799  0.071241       -0.046671          0.266050
#
# ...

# %% [markdown]
# ## Key Insights
#
# 1. Hypothesis: Age and Sleep efficiency are positively correlated. (Counterintuitive)
#     Justification: The correlation coefficient between Age and Sleep efficiency is 0.124093, indicating a weak positive correlation.
#
# 2. Hypothesis: Sleep duration and Sleep efficiency are negatively correlated.
#     Justification: The correlation coefficient between Sleep duration and Sleep efficiency is -0.019164, suggesting a weak negative correlation.
#
# 3. Hypothesis:  p percentage and Sleep efficiency are positively correlated.
#     Justification: The correlation coefficient between Deep sleep percentage and Sleep efficiency is 0.789087, indicating a strong positive correlation.
#
# 4. Hypothesis: Light sleep percentage and Sleep efficiency are negatively correlated.
#     Justification: The correlation coefficient between Light sleep percentage and Sleep efficiency is -0.816934, suggesting a strong negative correlation.
#
# 5. Hypothesis: Awakenings and Sleep efficiency are negatively correlated.
#     Justification: The correlation coefficient between Awakenings and Sleep efficiency is -0.567885, indicating a moderate negative correlation.

# %% [markdown]
# # *Testing Hypothesis*

# %% [markdown]
# ### Hypothesis 1:
#  Age and Sleep efficiency are positively correlated.
# (Counterintuitive) Justification: The correlation coefficient between Age and Sleep efficiency is 0.124093, indicating a weak positive correlation.

# %%
age = data_frame.sort_values('Age')
age.head(5)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 52    53    9  Female  2021-11-27 01:00:00  2021-11-27 09:30:00
# 211  212   10  Female  2021-07-15 01:00:00  2021-07-15 08:00:00
# 9     10   11  Female  2021-09-16 01:00:00  2021-09-16 10:00:00
# 332  333   12  Female  2021-11-01 01:00:00  2021-11-01 10:00:00
# 219  220   13  Female  2021-03-11 01:00:00  2021-03-11 09:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 52              8.5              0.52                    18
# 211             7.0              0.54                    18
# 9               9.0              0.55                    18
# 332             9.0              0.56                    18
# 219             8.0              0.58                    18
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 52                      35                      47         2.0
# 211                     35                      47         3.0
# ...

# %%
age.plot(x='Age', y= 'Sleep efficiency', kind= 'scatter')
# Out:
# <Axes: xlabel='Age', ylabel='Sleep efficiency'>

# %%
age.plot(x='Age', y= 'Sleep efficiency', kind= 'line')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### Conclusion 1:
#  This hypothesis seems contraversial and the data does not suggest strong correlation

# %% [markdown]
# ### Hypothesis 2:
# Sleep duration and Sleep efficiency are negatively correlated. Justification: The correlation coefficient between Sleep duration and Sleep efficiency is -0.019164, suggesting a weak negative correlation.

# %%
sleep = data_frame.sort_values('Sleep duration')
sleep.head()
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 90    91   45    Male  2021-03-29 02:30:00  2021-03-29 07:30:00
# 367  368   56    Male  2021-08-03 02:30:00  2021-08-03 07:30:00
# 232  233   36  Female  2021-03-06 23:00:00  2021-03-06 04:00:00
# 198  199   32  Female  2021-12-31 01:30:00  2021-12-31 06:30:00
# 110  111   51    Male  2021-06-18 00:30:00  2021-06-18 05:30:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 90              5.0              0.80                    24
# 367             5.0              0.74                    22
# 232             5.0              0.87                    22
# 198             5.0              0.86                    20
# 110             5.0              0.91                    23
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 90                      60                      16         4.0
# 367                     59                      19         1.0
# ...

# %%
sleep.plot(x= 'Sleep duration', y='Sleep efficiency')
# Out:
# <Axes: xlabel='Sleep duration'>

# %%
sleep.plot(x= 'Sleep duration', y='Sleep efficiency', kind='scatter')
# Out:
# <Axes: xlabel='Sleep duration', ylabel='Sleep efficiency'>

# %% [markdown]
# #### Conclusion 2:
# This hypothesis also seems counterintuitive, we must all factor in various other aspects...

# %% [markdown]
# ### Hypothesis 3:
# deep sleep percentage and Sleep efficiency are positively correlated. Justification: The correlation coefficient between Deep sleep percentage and Sleep efficiency is 0.789087, indicating a strong positive correlation.

# %%
sleep.plot(x='Deep sleep percentage', y='Sleep efficiency')
# Out:
# <Axes: xlabel='Deep sleep percentage'>

# %%
sleep.plot(x='Deep sleep percentage', y='Sleep efficiency', kind='scatter')
# Out:
# <Axes: xlabel='Deep sleep percentage', ylabel='Sleep efficiency'>

# %% [markdown]
# #### Conclusion 3:
# seems very logical and strong data inference we can confidently stipulate that higher deep sleep percentage causes better sleep efficieny

# %% [markdown]
# On an off note we can also check against rem sleep

# %%
sleep.plot(x='Sleep efficiency', y='REM sleep percentage')
# Out:
# <Axes: xlabel='Sleep efficiency'>

# %%
sleep.plot(x='Sleep efficiency', y='REM sleep percentage', kind='scatter')
# Out:
# <Axes: xlabel='Sleep efficiency', ylabel='REM sleep percentage'>

# %% [markdown]
# ### Hypothesis 4:
# Light sleep percentage and Sleep efficiency are negatively correlated. Justification: The correlation coefficient between Light sleep percentage and Sleep efficiency is -0.816934, suggesting a strong negative correlation.

# %%
sleep.plot(x='Sleep efficiency', y='Light sleep percentage', kind='scatter')
# Out:
# <Axes: xlabel='Sleep efficiency', ylabel='Light sleep percentage'>

# %%
sleep.plot(x='Sleep efficiency', y='Light sleep percentage', kind='line')
# Out:
# <Axes: xlabel='Sleep efficiency'>

# %% [markdown]
# ### Hypothesis 5:
# Awakenings and Sleep efficiency are negatively correlated. Justification: The correlation coefficient between Awakenings and Sleep efficiency is -0.567885, indicating a moderate negative correlation.

# %%
sleep.plot(x='Sleep efficiency', y='Awakenings', kind='scatter')
# Out:
# <Axes: xlabel='Sleep efficiency', ylabel='Awakenings'>

# %% [markdown]
# ### Conclusion
# No strong actionable points found hence further ahead we will segregate the data in age bands to find trends.

# %% [markdown]
# # *Filtering Data*

# %% [markdown]
# ### Age group 0 - 10

# %%
group1 = data_frame[data_frame.Age <= 10]
group1.describe()
# Out:
#                ID        Age  Sleep duration  Sleep efficiency  \
# count    2.000000   2.000000         2.00000          2.000000
# mean   132.500000   9.500000         7.75000          0.530000
# std    112.429978   0.707107         1.06066          0.014142
# min     53.000000   9.000000         7.00000          0.520000
# 25%     92.750000   9.250000         7.37500          0.525000
# 50%    132.500000   9.500000         7.75000          0.530000
# 75%    172.250000   9.750000         8.12500          0.535000
# max    212.000000  10.000000         8.50000          0.540000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count                   2.0                    2.0                     2.0
# mean                   18.0                   35.0                    47.0
# std                     0.0                    0.0                     0.0
# min                    18.0                   35.0                    47.0
# ...

# %% [markdown]
# ## Too small data set

# %% [markdown]
# ### Age group 10 - 20

# %%
group2 = data_frame[data_frame.Age <= 20]
group2.describe()
# Out:
#                ID        Age  Sleep duration  Sleep efficiency  \
# count   18.000000  18.000000       18.000000         18.000000
# mean   186.388889  15.777778        8.000000          0.685556
# std    139.046390   3.456546        0.747545          0.129352
# min     10.000000   9.000000        7.000000          0.520000
# 25%     54.250000  13.250000        7.500000          0.585000
# 50%    176.500000  17.500000        8.000000          0.640000
# 75%    272.500000  18.000000        8.500000          0.835000
# max    452.000000  20.000000        9.000000          0.910000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count             18.000000              18.000000               18.000000
# mean              19.611111              43.000000               37.388889
# std                2.569937              16.003676               15.882432
# min               15.000000              23.000000               12.000000
# ...

# %%
group1 = data_frame[data_frame.Age <= 10]
group1.describe()
# Out:
#                ID        Age  Sleep duration  Sleep efficiency  \
# count    2.000000   2.000000         2.00000          2.000000
# mean   132.500000   9.500000         7.75000          0.530000
# std    112.429978   0.707107         1.06066          0.014142
# min     53.000000   9.000000         7.00000          0.520000
# 25%     92.750000   9.250000         7.37500          0.525000
# 50%    132.500000   9.500000         7.75000          0.530000
# 75%    172.250000   9.750000         8.12500          0.535000
# max    212.000000  10.000000         8.50000          0.540000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count                   2.0                    2.0                     2.0
# mean                   18.0                   35.0                    47.0
# std                     0.0                    0.0                     0.0
# min                    18.0                   35.0                    47.0
# ...
